# %%
import tensorflow as tf
import pandas as pd

# %%
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

# %%
test.head(5)
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_195453  01-FEB-18    0   30   35    7    3    6    4    0    5     1
# 1   CR_103520  05-MAR-04    0   44   44    1    3    7    1    4    6     1
# 2   CR_196089  27-JAN-18    0   34   33    3    5    2    7    3    0     1
# 3   CR_112195  18-AUG-06    7    3    2    3    5    9    8    0    5     1
# 4   CR_149832  31-OCT-11    0    7    8    7    3    2    7    1    5     1
#
#    X_11  X_12  X_13  X_14  X_15
# 0   174   NaN    72   119    23
# 1   316   0.0    12    29    34
# 2   316   1.0    72     0    34
# 3   174   1.0   112    87    34
# 4   174   0.0   112    93    43
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_195453  01-FEB-18    0   30   35    7    3    6    4    0    5     1
# 1   CR_103520  05-MAR-04    0   44   44    1    3    7    1    4    6     1
# 2   CR_196089  27-JAN-18    0   34   33    3    5    2    7    3    0     1
# ...

# %%
df=train.loc[:,'X_1':'MULTIPLE_OFFENSE']

# %%
df.dropna(axis = 0, how ='any',inplace=True)

# %%
df.describe()
# Out:
#                 X_1           X_2           X_3           X_4           X_5  \
# count  23674.000000  23674.000000  23674.000000  23674.000000  23674.000000
# mean       0.481287     24.792895     24.644547      4.279463      2.457886
# std        1.435650     15.249384     15.148753      2.947699      1.964675
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      7.000000      8.000000      2.000000      1.000000
# 50%        0.000000     24.000000     24.000000      4.000000      3.000000
# 75%        0.000000     36.000000     35.000000      6.000000      5.000000
# max        7.000000     52.000000     52.000000     10.000000      5.000000
#
#                 X_6           X_7           X_8           X_9          X_10  \
# count  23674.000000  23674.000000  23674.000000  23674.000000  23674.000000
# mean       6.159965      4.881304      0.974867      4.924263      1.246557
# ...

# %%
df.sample(frac=1).reset_index(drop=True)
# Out:
#        X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  X_11  X_12  X_13  \
# 0        0   26   27    9    0    3    5    1    6     1   316   1.0   109
# 1        0    4    4    6    5    1    0    0    5     1   174   1.0   103
# 2        1   24   24    0    0   12   16    1    5     1     0   1.0    98
# 3        0   21   23    4    1    2    7    1    6     1   316   1.0    92
# 4        1   36   34    2    1   15   10    0    5     1   249   1.0    92
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...   ...
# 23669    0    4    4    6    5    2    7    3    6     1   316   1.0   112
# 23670    0   49   49    6    5    2    7    1    6     2   249   2.0    72
# 23671    0   26   27    9    0    7    1    0    5     2   174   2.0   103
# 23672    0   49   49    6    5    4    2    1    6     1   249   1.0   112
# 23673    0   33   32    2    1    5    6    1    6     1   249   1.0   109
#
#        X_14  X_15  MULTIPLE_OFFENSE
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X= df.loc[:,'X_1':'X_15']
Y=df.loc[:,['MULTIPLE_OFFENSE']]

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.3)

# %%
'''
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='report.html')'''

# %%
import matplotlib.pyplot as plt

# %%
def create_test_input_fn():
    return tf.estimator.inputs.pandas_input_fn(
        x=x_test,
        y=y_test['MULTIPLE_OFFENSE'], 
        num_epochs=1, # Just one epoch
        shuffle=False)

# %%
def create_train_input_fn():
    return tf.estimator.inputs.pandas_input_fn(
        x=x_train,
        y=y_train['MULTIPLE_OFFENSE'], 
        batch_size=1000,
        num_epochs=25, # Just one epoch
        shuffle=True)

# %%
feature_columns=[]
X_1=tf.feature_column.numeric_column('X_1')
X_2=tf.feature_column.numeric_column('X_2')
X_3=tf.feature_column.numeric_column('X_3')
X_4=tf.feature_column.numeric_column('X_4')
X_5=tf.feature_column.numeric_column('X_5')
X_6=tf.feature_column.numeric_column('X_6')
X_7=tf.feature_column.numeric_column('X_7')
X_8=tf.feature_column.numeric_column('X_8')
X_9=tf.feature_column.numeric_column('X_9')
X_10=tf.feature_column.numeric_column('X_10')
X_11=tf.feature_column.numeric_column('X_11')
X_12=tf.feature_column.numeric_column('X_12')
X_13=tf.feature_column.numeric_column('X_13')
X_14=tf.feature_column.numeric_column('X_14')
X_15=tf.feature_column.numeric_column('X_15')
feature_columns.extend([X_1,X_2,X_3,X_4,X_5,X_6,X_7,X_8,X_9,X_10,X_11,X_12,X_13,X_14,X_15])

# %%
train_input_fn = create_train_input_fn()
estimator = tf.estimator.LinearClassifier(feature_columns,model_dir='graphs/linear', n_classes=2)
estimator.train(train_input_fn, steps=1000)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0618 11:16:09.642272  4148 deprecation.py:323] From E:\anaconda\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0618 11:16:09.798500  4148 deprecation.py:323] From E:\anaconda\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# ...

# %%
test_input_fn = create_test_input_fn()
estimator.evaluate(test_input_fn)
# Out:
# W0618 11:17:10.891597  4148 deprecation.py:323] From E:\anaconda\lib\site-packages\tensorflow\python\ops\metrics_impl.py:2027: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0618 11:17:12.704011  4148 metrics_impl.py:804] Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# W0618 11:17:12.844649  4148 metrics_impl.py:804] Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# {'accuracy': 0.9572012,
#  'accuracy_baseline': 0.95663804,
#  'auc': 0.8135313,
#  'auc_precision_recall': 0.98856604,
#  'average_loss': 0.16155262,
#  'label/mean': 0.95663804,
#  'loss': 20.49122,
#  'precision': 0.9583392,
#  'prediction/mean': 0.9779803,
#  'recall': 0.9986755,
#  'global_step': 889}

# %%
estimator2 = tf.estimator.DNNClassifier(hidden_units=[128, 64,32,16], 
                                       feature_columns=feature_columns, 
                                       n_classes=2, 
                                       model_dir='graphs/dnn')

# %%
train_input_fn = create_train_input_fn()
estimator2.train(train_input_fn, steps=2000)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0618 11:55:45.152919 13692 deprecation.py:323] From E:\anaconda\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING: Logging before flag parsing goes to stderr.
# W0618 11:55:45.152919 13692 deprecation.py:323] From E:\anaconda\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# ...

# %%
test_input_fn = create_test_input_fn()
estimator2.evaluate(test_input_fn)
# Out:
# W0618 11:56:51.731085 13692 deprecation.py:323] From E:\anaconda\lib\site-packages\tensorflow\python\ops\metrics_impl.py:2027: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0618 11:56:51.731085 13692 deprecation.py:323] From E:\anaconda\lib\site-packages\tensorflow\python\ops\metrics_impl.py:2027: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0618 11:56:52.955658 13692 metrics_impl.py:804] Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# W0618 11:56:52.955658 13692 metrics_impl.py:804] Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# ...

# %%
def create_input_fn():
    return tf.estimator.inputs.pandas_input_fn(
        x=test.loc[:,'X_1':'X_15'],
        shuffle=False
        )

# %%
predictions=estimator2.predict(create_input_fn())

# %%
classes=[0,1]
result=[]
for pred_dict in (predictions):
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]
    result.append(classes[class_id])

# %%
print(len(result))
# Out:
# 15903
# 15903

# %%
sample=pd.read_csv("sample_submission.csv")

# %%
sample.head()
# Out:
#   INCIDENT_ID MULTIPLE_OFFENSE
# 0   CR_195453                1
# 1   CR_103520                0
# 2           .                .
# 3           .                .
# 4   CR_196089                1
#   INCIDENT_ID MULTIPLE_OFFENSE
# 0   CR_195453                1
# 1   CR_103520                0
# 2           .                .
# 3           .                .
# 4   CR_196089                1

# %%
test['MULTIPLE_OFFENSE']=result

# %%
test.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_195453  01-FEB-18    0   30   35    7    3    6    4    0    5     1
# 1   CR_103520  05-MAR-04    0   44   44    1    3    7    1    4    6     1
# 2   CR_196089  27-JAN-18    0   34   33    3    5    2    7    3    0     1
# 3   CR_112195  18-AUG-06    7    3    2    3    5    9    8    0    5     1
# 4   CR_149832  31-OCT-11    0    7    8    7    3    2    7    1    5     1
#
#    X_11  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0   174   NaN    72   119    23                 0
# 1   316   0.0    12    29    34                 1
# 2   316   1.0    72     0    34                 1
# 3   174   1.0   112    87    34                 1
# 4   174   0.0   112    93    43                 1
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_195453  01-FEB-18    0   30   35    7    3    6    4    0    5     1
# ...

# %%
submission=test[['INCIDENT_ID','MULTIPLE_OFFENSE']]

# %%
submission.head()
# Out:
#   INCIDENT_ID  MULTIPLE_OFFENSE
# 0   CR_195453                 0
# 1   CR_103520                 1
# 2   CR_196089                 1
# 3   CR_112195                 1
# 4   CR_149832                 1
#   INCIDENT_ID  MULTIPLE_OFFENSE
# 0   CR_195453                 0
# 1   CR_103520                 1
# 2   CR_196089                 1
# 3   CR_112195                 1
# 4   CR_149832                 1

# %%
submission.to_csv('mysubmission.csv')
